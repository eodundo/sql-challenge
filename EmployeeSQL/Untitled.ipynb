# %%
# !pip install psycopg2
# Out:
# ...
#   Using cached psycopg2-2.8.6.tar.gz (383 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/Liz/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/5b/c6g1tv3d6ys4l295_bm6vw3c0000gn/T/pip-install-5wmw7pnm/psycopg2_41a31495b462491eb5aed4f9bb4e6450/setup.py'"'"'; __file__='"'"'/private/var/folders/5b/c6g1tv3d6ys4l295_bm6vw3c0000gn/T/pip-install-5wmw7pnm/psycopg2_41a31495b462491eb5aed4f9bb4e6450/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/5b/c6g1tv3d6ys4l295_bm6vw3c0000gn/T/pip-pip-egg-info-c25apl9o
#          cwd: /private/var/folders/5b/c6g1tv3d6ys4l295_bm6vw3c0000gn/T/pip-install-5wmw7pnm/psycopg2_41a31495b462491eb5aed4f9bb4e6450/
# ...
